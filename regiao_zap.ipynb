# %% [markdown]
# Tenta melhorar a questão de região não definida

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import kagglehub
import subprocess
import os

# %%
fonte_dados = 'a'  # 'a', 'c', 'b'

if fonte_dados == 'a':
    df = pd.read_csv('aluguel_blumenau_25_10_27.csv')
elif fonte_dados == 'c':
    df = pd.read_csv('compra_blumenau_25_10_27.csv')
df
# Out:
#                                              Localidade  \
# 0     Imóvel para alugar com 210 m² em Salto do Nort...
# 1     Apartamento para alugar com 108 m², 3 quartos,...
# 2     Galpão/Depósito/Armazém para alugar com 450 m²...
# 3     Apartamento para alugar com 46 m², 2 quartos, ...
# 4     Casa para alugar com 180 m², 5 quartos, 2 banh...
# ...                                                 ...
# 3121  Apartamento para alugar com 45 m², 1 quarto, 1...
# 3122  Apartamento para alugar com 45 m², 1 quarto, 1...
# 3123  Apartamento para alugar com 45 m², 1 quarto, 1...
# 3124  Apartamento para alugar com 90 m², 2 quartos, ...
# 3125  Sala/Conjunto para alugar com 47 m², 1 banheir...
#
#                          Endereco     M2   Preco      R$/M2   Latitude  \
# 0     Rua Doutor Pedro Zimmermann  210.0  7500.0  35.714286 -26.859167
# 1           Rua Benjamin Constant  108.0  2900.0  26.851852 -26.889516
# 2                             NaN  450.0  7600.0  16.888889 -27.079758
# 3            Rua Dois de Setembro   46.0  1400.0  30.434783 -26.876203
# 4                  Rua João Gomes  180.0  2500.0  13.888889 -26.899939
# ...                           ...    ...     ...        ...        ...
# 3121                          NaN   45.0  1700.0  37.777778 -27.079758
# 3122                          NaN   45.0  1950.0  43.333333 -27.079758
# 3123                          NaN   45.0  1950.0  43.333333 -27.079758
# 3124                          NaN   90.0  1790.0  19.888889 -27.079758
# 3125                          NaN   47.0  2200.0  46.808511 -27.079758
#
#       Longitude                     Tipo  Quarto  Banheiro  Vaga
# 0    -49.086042                   Imóvel       0         0     0
# 1    -49.097449              Apartamento       3         2     2
# 2    -48.910080  Galpão/Depósito/Armazém       0         0     0
# 3    -49.087410              Apartamento       2         1     0
# 4    -49.093511                     Casa       5         2     2
# ...         ...                      ...     ...       ...   ...
# 3121 -48.910080              Apartamento       1         1     0
# 3122 -48.910080              Apartamento       1         1     0
# 3123 -48.910080              Apartamento       1         1     0
# 3124 -48.910080              Apartamento       2         2     1
# 3125 -48.910080            Sala/Conjunto       0         1     2
#
# [3126 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3126 entries, 0 to 3125
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Localidade  3126 non-null   object
#  1   Endereco    1572 non-null   object
#  2   M2          3126 non-null   float64
#  3   Preco       3126 non-null   float64
#  4   R$/M2       3126 non-null   float64
#  5   Latitude    3104 non-null   float64
#  6   Longitude   3104 non-null   float64
#  7   Tipo        3126 non-null   object
#  8   Quarto      3126 non-null   int64
#  9   Banheiro    3126 non-null   int64
#  10  Vaga        3126 non-null   int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 268.8+ KB

# %%
df.isnull().sum()
# Out:
# Localidade       0
# Endereco      1554
# M2               0
# Preco            0
# R$/M2            0
# Latitude        22
# Longitude       22
# Tipo             0
# Quarto           0
# Banheiro         0
# Vaga             0
# dtype: int64

# %%
df[df['Endereco'].isnull()]
# Out:
#                                              Localidade Endereco     M2  \
# 2     Galpão/Depósito/Armazém para alugar com 450 m²...      NaN  450.0
# 18    Apartamento para alugar com 110 m², 2 quartos,...      NaN  110.0
# 20    Apartamento para alugar com 76 m², 2 quartos, ...      NaN   76.0
# 24    Cobertura para alugar com 68 m², 2 quartos, 3 ...      NaN   68.0
# 25    Apartamento para alugar com 73 m², 1 quarto, 3...      NaN   73.0
# ...                                                 ...      ...    ...
# 3121  Apartamento para alugar com 45 m², 1 quarto, 1...      NaN   45.0
# 3122  Apartamento para alugar com 45 m², 1 quarto, 1...      NaN   45.0
# 3123  Apartamento para alugar com 45 m², 1 quarto, 1...      NaN   45.0
# 3124  Apartamento para alugar com 90 m², 2 quartos, ...      NaN   90.0
# 3125  Sala/Conjunto para alugar com 47 m², 1 banheir...      NaN   47.0
#
#        Preco      R$/M2   Latitude  Longitude                     Tipo  \
# 2     7600.0  16.888889 -27.079758  -48.91008  Galpão/Depósito/Armazém
# 18    1900.0  17.272727 -27.079758  -48.91008              Apartamento
# 20    2400.0  31.578947 -27.079758  -48.91008              Apartamento
# 24    3500.0  51.470588 -27.079758  -48.91008                Cobertura
# 25    1590.0  21.780822 -27.079758  -48.91008              Apartamento
# ...      ...        ...        ...        ...                      ...
# 3121  1700.0  37.777778 -27.079758  -48.91008              Apartamento
# 3122  1950.0  43.333333 -27.079758  -48.91008              Apartamento
# 3123  1950.0  43.333333 -27.079758  -48.91008              Apartamento
# 3124  1790.0  19.888889 -27.079758  -48.91008              Apartamento
# 3125  2200.0  46.808511 -27.079758  -48.91008            Sala/Conjunto
#
#       Quarto  Banheiro  Vaga
# 2          0         0     0
# 18         2         3     1
# 20         2         3     2
# 24         2         3     1
# 25         1         3     1
# ...      ...       ...   ...
# 3121       1         1     0
# 3122       1         1     0
# 3123       1         1     0
# 3124       2         2     1
# 3125       0         1     2
#
# [1554 rows x 11 columns]
